# %% [markdown]
# # Plotting & Downloading
# > plot json data and download an plotted image

# %%
#| default_exp plotting

# %%
#| hide
from nbdev.showdoc import *

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

# Sample DataFrame
json_data = '''
[
    {"name": "A", "value": 10},
    {"name": "B", "value": 15},
    {"name": "C", "value": 7}
]
'''

# Convert JSON to DataFrame
data = json.loads(json_data)
df = pd.DataFrame(data)

# Generate a plot
ax = df.plot(x='name', y='value', kind='bar', title='Sample Plot')

# Save the plot
plt.savefig('plot_image.png')  # Save as PNG (can use other formats like .jpg, .pdf, etc.)

# Show the plot (optional)
plt.show()

# %%
#| hide
import nbdev; nbdev.nbdev_export()
